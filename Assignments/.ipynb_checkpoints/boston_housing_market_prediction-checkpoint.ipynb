# %% [markdown]
# ## Imports

# %%
# CUSTOM FUNCTIONS
import sys
sys.path.insert(0, "../")
from custom_tools import corrplot_

# ANALYSIS
import pandas as pd
import numpy as np

# VISUALISATION
import matplotlib.pyplot as plt
import seaborn as sns
# Allows charts to appear in notebook
# %matplotlib inline

# MACHINE LEARNING
from sklearn.datasets import load_boston
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # SECTION 1: *Data Analysis*

# %%
boston = load_boston()
print(boston.DESCR)
# Out:
# .. _boston_dataset:
#
# Boston house prices dataset
# ---------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive. Median Value (attribute 14) is usually the target.
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
# ...

# %% [markdown]
# ### Dataframe, target prediction, features

# %%
df_boston = pd.DataFrame(boston.data, columns=boston.feature_names)
df_target = pd.DataFrame(boston.target, columns=["MEDV"])

df_boston.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df_boston.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
df_target.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
housing_features = df_boston.loc[:, 'CRIM':'PTRATIO']
housing_features.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  PTRATIO
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0     18.7

# %% [markdown]
# ## Visualistion

# %%
def plot_two_features(independent_variable, dependent_variable="MEDV"):
    """ Visualizes the scatterplot of data across two features. """
    if dependent_variable == "MEDV":
        plt.scatter(df_boston[independent_variable], df_target[dependent_variable])
    else:
        plt.scatter(df_target[independent_variable], df_boston[dependent_variable])
    plt.xlabel(independent_variable)
    plt.ylabel(dependent_variable)

# %%
plot_two_features("DIS")

# %% [markdown]
# ## Correllation heatmap

# %%
df_corr_plot = pd.concat([df_boston, df_target], axis=1)
corrplot_(df_corr_plot)

# %% [markdown]
# # SECTION 2: *Machine Learning*

# %% [markdown]
# ### STEP 1: Instantiating Linear Regression Model

# %%
lr_model = LinearRegression()

# %% [markdown]
# ### STEP 2: Data Normalisation
# - To improve prediction results

# %%
min_max_scaler = preprocessing.MinMaxScaler()
X_minmax = min_max_scaler.fit_transform(housing_features)
print(X_minmax)
# Out:
# [[0.00000000e+00 1.80000000e-01 6.78152493e-02 ... 0.00000000e+00
#   2.08015267e-01 2.87234043e-01]
#  [2.35922539e-04 0.00000000e+00 2.42302053e-01 ... 4.34782609e-02
#   1.04961832e-01 5.53191489e-01]
#  [2.35697744e-04 0.00000000e+00 2.42302053e-01 ... 4.34782609e-02
#   1.04961832e-01 5.53191489e-01]
#  ...
#  [6.11892474e-04 0.00000000e+00 4.20454545e-01 ... 0.00000000e+00
#   1.64122137e-01 8.93617021e-01]
#  [1.16072990e-03 0.00000000e+00 4.20454545e-01 ... 0.00000000e+00
#   1.64122137e-01 8.93617021e-01]
#  [4.61841693e-04 0.00000000e+00 4.20454545e-01 ... 0.00000000e+00
#   1.64122137e-01 8.93617021e-01]]

# %% [markdown]
# ### STEP 3: Data split into test & train

# %%
X, y = np.array(df_boston["LSTAT"]).reshape(-1, 1), np.array(df_target["MEDV"]).reshape(-1, 1)
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, test_size=0.2)

# %% [markdown]
# ### STEP 4: Fit model to training data

# %%
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# ### STEP 5: Precict data using fitted model against test data (`X_test`)

# %%
y_pred = lr_model.predict(X_test)

# %% [markdown]
# ### STEP 6: Compare `y_pred` with `y_test` using r^2 score & MSE

# %%
rsq = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)

# %% [markdown]
# A low R^2 score

# %%
rsq
# Out:
# 0.444445220465543

# %%
mse
# Out:
# 40.235400779942864

# %% [markdown]
# ### STEP 6: Repeat above steps with min max scaling

# %%
_, y = np.array(df_boston["LSTAT"]).reshape(-1, 1), np.array(df_target["MEDV"]).reshape(-1, 1)
X_minmax, X_test, y_train, y_test = train_test_split(X_minmax, y, train_size=0.8, test_size=0.2)

# %%
lr_model_2 = LinearRegression()
lr_model_2.fit(X_minmax, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_test_minmax = min_max_scaler.fit_transform(X_test)
y_pred = lr_model_2.predict(X_test_minmax)
y_pred
# Out:
# array([[ 20.94481968],
#        [  6.11704179],
#        [ 20.64153329],
#        [ 12.52514251],
#        [ 25.85864407],
#        [ 19.89866732],
#        [ 20.04256148],
#        [ 28.94204817],
#        [ 10.86289262],
#        [ 23.98191275],
#        [ 15.98897602],
#        [  6.71369899],
#        [  7.92831184],
#        [ 21.03766249],
#        [ 21.05574285],
#        [ 15.4295968 ],
#        [ 23.79203787],
#        [ 39.92866397],
#        [ 38.04947689],
#        [ 22.31090781],
#        [ 35.77973638],
#        [ 13.13404567],
#        [ 22.44820027],
#        [ 14.43668287],
#        [ 34.95745489],
#        [ 12.06557724],
#        [ 21.33256869],
#        [ 45.59094659],
#        [ 27.3502561 ],
#        [ 19.38536033],
#        [ 32.93403496],
#        [ 25.08972919],
#        [ 17.848573  ],
#        [ 26.27161223],
#        [  1.93487557],
#        [ 18.36491573],
#        [  6.50931894],
#        [ 16.88559027],
#        [ 21.47237101],
#        [ 22.31508628],
# ...

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5084461099348692

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 35.67184846754997

# %% [markdown]
# ### STEP 7: Repeate steps with standard scaling

# %%
standard_scaler = preprocessing.StandardScaler()
X_standard_scaler = standard_scaler.fit_transform(X)
print(X_standard_scaler)
# Out:
# [[-1.07556230e+00]
#  [-4.92439366e-01]
#  [-1.20872740e+00]
#  [-1.36151682e+00]
#  [-1.02650148e+00]
#  [-1.04332233e+00]
#  [-3.12676184e-02]
#  [ 9.10700206e-01]
#  [ 2.42177359e+00]
#  [ 6.23343950e-01]
#  [ 1.09292612e+00]
#  [ 8.64783596e-02]
#  [ 4.28502391e-01]
#  [-6.15792295e-01]
#  [-3.35444728e-01]
#  [-5.86355801e-01]
#  [-8.51284251e-01]
#  [ 2.82721656e-01]
#  [-1.34996218e-01]
#  [-1.92467469e-01]
#  [ 1.17282518e+00]
#  [ 1.64975678e-01]
#  [ 8.50425479e-01]
#  [ 1.01302707e+00]
#  [ 5.11204923e-01]
#  [ 5.40641418e-01]
#  [ 3.02345986e-01]
#  [ 6.48575231e-01]
#  [ 2.05966814e-02]
#  [-9.43458210e-02]
#  [ 1.39429976e+00]
#  [ 5.42383894e-02]
#  [ 2.11058779e+00]
#  [ 7.98561179e-01]
#  [ 1.07750701e+00]
#  [-4.16745523e-01]
#  [-1.74244877e-01]
#  [-5.44303666e-01]
#  [-3.53667320e-01]
#  [-1.16807700e+00]
#  [-1.49608365e+00]
#  [-1.09518663e+00]
#  [-9.59218064e-01]
#  [-7.30734797e-01]
#  [-4.34968115e-01]
#  [-3.42453418e-01]
#  [ 2.09831289e-01]
# ...

# %%
_, y = np.array(df_boston["LSTAT"]).reshape(-1, 1), np.array(df_target["MEDV"]).reshape(-1, 1)
X_standard_scaler, X_test, y_train, y_test = train_test_split(X_standard_scaler, y, train_size=0.8, test_size=0.2)

# %%
lr_model_3 = LinearRegression()
lr_model_3.fit(X_standard_scaler, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_test_standard_scaler = standard_scaler.fit_transform(X_test)
y_pred = lr_model_3.predict(X_test_standard_scaler)
y_pred
# Out:
# array([[19.34094694],
#        [34.34776658],
#        [22.28575495],
#        [16.74717564],
#        [15.42103693],
#        [21.80795497],
#        [11.74490243],
#        [31.46146469],
#        [20.29654689],
#        [27.44404448],
#        [17.70277559],
#        [19.71148569],
#        [19.31169388],
#        [21.4276652 ],
#        [26.97599553],
#        [20.23804077],
#        [21.70069376],
#        [32.58283198],
#        [16.23037159],
#        [27.37578734],
#        [21.87621211],
#        [21.74944886],
#        [24.30421607],
#        [27.98035058],
#        [25.9326364 ],
#        [31.12993001],
#        [23.91417528],
#        [30.97391369],
#        [12.93452686],
#        [27.6000608 ],
#        [26.84923227],
#        [29.83304436],
#        [10.99407389],
#        [25.09404868],
#        [29.34549337],
#        [31.06167287],
#        [28.82868931],
#        [27.01499961],
#        [10.88681268],
#        [19.25318776],
#        [21.64218764],
# ...

# %%
r2_score(y_test, y_pred)
# Out:
# 0.5084461099348692

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 35.67184846754997

# %% [markdown]
# # Conclusion

# %% [markdown]
# We used three models here all with different scaling:
# - No Scaling
# - Min max scaling
# - Standard scaling
#
# With all of these we computed their r2 scores and MSE
# - No Scaling
#  - r2 - 0.444445220465543
#  - MSE - 40.235400779942864
# - Min max scaling
#  - r2 - 0.5084461099348692
#  - MSE - 35.67184846754997
# - Standard scaling
#  - r2 - 0.5084461099348692
#  - MSE - 35.67184846754997
